# %% [markdown]
# # 1. Importation de notre bibliothèque

# %%
import pandas as pd

# %% [markdown]
# # 2. Importation de notre dataset

# %%
df = pd.read_csv("YugiOh - Feuille 1.csv")

# %%
df
# Out:
#                                Nom      Type_1                  Type_2  \
# 0      Temple Chronomal - Trilithe       Magie                     NaN
# 1               1er Mouvement Solo       Magie                     NaN
# 2                  À Forces Égales       Piège                     NaN
# 3                A Jamais Destinés       Piège                     NaN
# 4              À la Recherche d'Or  Compétence        [ Compétence / ]
# ...                            ...         ...                     ...
# 10831          ZW - Lance Unicorne     Monstre        [ Bête / Effet ]
# 10832     ZW - Pégase Double Sabre     Monstre        [ Bête / Effet ]
# 10833      ZW - Porteur de Tornade     Monstre      [ Dragon / Effet ]
# 10834          ZW - Serres d'Aigle     Monstre  [ Bête-Ailée / Effet ]
# 10835           ZW - Vent Sylphide     Monstre        [ Bête / Effet ]
#
#          Icône                                        Description  Niveau  \
# ...

# %% [markdown]
# # origine: inspirer d'un mangas et jeu de carte
# # Circonstances de creation: on voulait mener une campagne publicitaire sur l'animé
# # prévisions sur le dataset : des previsions peuvent être faite au niveau du type de carte et du prix
# # bref apercu : on constatte des NaN (not a number_valeur non renseigner). on constate qu'il ya 10836 lignes et 10 colonnes

# %% [markdown]
# # 3. Affichons les dix premieres lignes du dataset

# %%
df.head(10)
# Out:
#                            Nom      Type_1             Type_2       Icône  \
# 0  Temple Chronomal - Trilithe       Magie                NaN     Continu
# 1           1er Mouvement Solo       Magie                NaN         NaN
# 2              À Forces Égales       Piège                NaN         NaN
# 3            A Jamais Destinés       Piège                NaN         NaN
# 4          À la Recherche d'Or  Compétence   [ Compétence / ]         NaN
# 5               À Moitié Fermé       Magie                NaN  Jeu Rapide
# 6              A.I. Vous défie       Piège                NaN     Continu
# 7          A.I. Vous Rencontre       Magie                NaN         NaN
# 8                        A.I.Q       Piège                NaN     Continu
# 9                        Abaki     Monstre  [ Démon / Effet ]         NaN
#
#                                          Description  Niveau Attribut   ATK  \
# 0  Si vous ne contrôlez aucun monstre, ou si tous...     NaN      NaN   NaN
# ...

# %% [markdown]
# # Affichons les dix dernières lignes du dataset

# %%
df.tail(10)
# Out:
#                               Nom   Type_1                    Type_2 Icône  \
# 10826        ZW - Armure Sleipnir  Monstre          [ Bête / Effet ]   NaN
# 10827        ZW - Bouclier Ultime  Monstre        [ Rocher / Effet ]   NaN
# 10828           ZW - Assaut Asura  Monstre          [ Elfe / Effet ]   NaN
# 10829       ZW - Lame Foudroyante  Monstre          [ Bête / Effet ]   NaN
# 10830  ZW - Hallebarde Dragonique  Monstre  [ Dragon / Effet / Xyz ]   NaN
# 10831         ZW - Lance Unicorne  Monstre          [ Bête / Effet ]   NaN
# 10832    ZW - Pégase Double Sabre  Monstre          [ Bête / Effet ]   NaN
# 10833     ZW - Porteur de Tornade  Monstre        [ Dragon / Effet ]   NaN
# 10834         ZW - Serres d'Aigle  Monstre    [ Bête-Ailée / Effet ]   NaN
# 10835          ZW - Vent Sylphide  Monstre          [ Bête / Effet ]   NaN
#
#                                              Description  Niveau  Attribut  \
# ...

# %% [markdown]
# # 5. Affichons les colonnes du dataset

# %%
df.columns
# Out:
# Index(['Nom', 'Type_1', 'Type_2', 'Icône', 'Description', 'Niveau', 'Attribut',
#        'ATK', 'DEF', 'Prix'],
#       dtype='object')

# %% [markdown]
# # 6. Affichons les colonnes du dataset en majuscule

# %%
df.columns.str.upper()
# Out:
# Index(['NOM', 'TYPE_1', 'TYPE_2', 'ICÔNE', 'DESCRIPTION', 'NIVEAU', 'ATTRIBUT',
#        'ATK', 'DEF', 'PRIX'],
#       dtype='object')

# %% [markdown]
# # 7. Affichons la taille du dataset

# %%
df.shape
# Out:
# (10836, 10)

# %% [markdown]
# # 8. Affichons les informations sur les types de colonnes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10836 entries, 0 to 10835
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nom          10836 non-null  object
#  1   Type_1       10836 non-null  object
#  2   Type_2       7123 non-null   object
#  3   Icône        1863 non-null   object
#  4   Description  10735 non-null  object
#  5   Niveau       6903 non-null   float64
#  6   Attribut     7021 non-null   object
#  7   ATK          6959 non-null   object
#  8   DEF          6959 non-null   object
#  9   Prix         10836 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 846.7+ KB

# %% [markdown]
# # Y a t'il des valeurs manquantes

# %%
df.isnull()
# Out:
#          Nom  Type_1  Type_2  Icône  Description  Niveau  Attribut    ATK  \
# 0      False   False    True  False        False    True      True   True
# 1      False   False    True   True        False    True      True   True
# 2      False   False    True   True        False    True      True   True
# 3      False   False    True   True        False    True      True   True
# 4      False   False   False   True        False    True      True   True
# ...      ...     ...     ...    ...          ...     ...       ...    ...
# 10831  False   False   False   True        False   False     False  False
# 10832  False   False   False   True        False   False     False  False
# 10833  False   False   False   True        False   False     False  False
# 10834  False   False   False   True        False   False     False  False
# 10835  False   False   False   True        False   False     False  False
#
#          DEF   Prix
# 0       True  False
# 1       True  False
# ...

# %% [markdown]
# # ici ca precise exactement combien il ya de valeurs manquantes pour chaque colonnes

# %%
df.isnull().sum()
# Out:
# Nom               0
# Type_1            0
# Type_2         3713
# Icône          8973
# Description     101
# Niveau         3933
# Attribut       3815
# ATK            3877
# DEF            3877
# Prix              0
# dtype: int64

# %% [markdown]
# # 9. Affichons les differentes occurences de la colonne 'type_2'

# %%
df["Type_2"].value_counts()
# Out:
# [ Guerrier / Effet ]            543
# [ Machine / Effet ]             451
# [ Démon / Effet ]               365
# [ Magicien / Effet ]            332
# [ Elfe / Effet ]                280
#                                ...
# [ Aqua / Spirit / Effet ]         1
# [ Insecte / Fusion / Effet ]      1
# [ Effet / Plante ]                1
# [ Reptile / Syntoniseur ]         1
# [ Dragon / Effet / Xyz ]          1
# Name: Type_2, Length: 468, dtype: int64

# %% [markdown]
# # 10. Affichons les cinq premieres lignes de la colonne 'description'

# %%
# pour cela on met d'abord la colonne description dans une variable et puis on affiche les cinq premieres lignes de la variable

# %%
x = df["Description"]

# %%
x
# Out:
# 0        Si vous ne contrôlez aucun monstre, ou si tous...
# 1        Si vous ne contrôlez aucun monstre : Invoquez ...
# 2        À la fin de la Battle Phase, si votre adversai...
# 3        Ciblez 2 monstres dans votre Cimetière ; Invoq...
# 4        Activation de Compétence\n Retournez cette car...
#                                ...
# 10831    Vous pouvez cibler 1 "Numéro C39 : Rayon Utopi...
# 10832    Vous ne pouvez contrôler qu'1 "ZW - Pégase Dou...
# 10833    Vous pouvez cibler 1 monstre ''Utopie'' que vo...
# 10834    Si votre adversaire a min. 2000 Life Points de...
# 10835    Vous ne pouvez contrôler qu'1 "ZW - Vent Sylph...
# Name: Description, Length: 10836, dtype: object

# %%
x.head(5)
# Out:
# 0    Si vous ne contrôlez aucun monstre, ou si tous...
# 1    Si vous ne contrôlez aucun monstre : Invoquez ...
# 2    À la fin de la Battle Phase, si votre adversai...
# 3    Ciblez 2 monstres dans votre Cimetière ; Invoq...
# 4    Activation de Compétence\n Retournez cette car...
# Name: Description, dtype: object

# %% [markdown]
# # avec un code plus optimisé et en une seule ligne

# %%
df["Description"].head(5)
# Out:
# 0    Si vous ne contrôlez aucun monstre, ou si tous...
# 1    Si vous ne contrôlez aucun monstre : Invoquez ...
# 2    À la fin de la Battle Phase, si votre adversai...
# 3    Ciblez 2 monstres dans votre Cimetière ; Invoq...
# 4    Activation de Compétence\n Retournez cette car...
# Name: Description, dtype: object

# %% [markdown]
# # 11.Affichons les cinq premieres lignes de la colonne 'description', 'type_2' et 'type_1'

# %% [markdown]
# # on va d'abord mettre les colonnes là dans une variable. Ensuite on va les concatenner pour en faire une

# %%
colonneDescription = df ["Description"]
colonneType_1 = df ["Type_1"]
colonneType_2 = df ["Type_2"]

# %%
dataframe = pd.concat([colonneDescription, colonneType_2, colonneType_1], axis = 1)
dataframe.head(5)
# Out:
#                                          Description            Type_2  \
# 0  Si vous ne contrôlez aucun monstre, ou si tous...               NaN
# 1  Si vous ne contrôlez aucun monstre : Invoquez ...               NaN
# 2  À la fin de la Battle Phase, si votre adversai...               NaN
# 3  Ciblez 2 monstres dans votre Cimetière ; Invoq...               NaN
# 4  Activation de Compétence\n Retournez cette car...  [ Compétence / ]
#
#        Type_1
# 0       Magie
# 1       Magie
# 2       Piège
# 3       Piège
# 4  Compétence

# %% [markdown]
# # avec un code plus optimisé et en une seule ligne

# %%
pd.concat([df ["Description"], df ["Type_2"], df ["Type_1"]], axis = 1).head(5)
# Out:
#                                          Description            Type_2  \
# 0  Si vous ne contrôlez aucun monstre, ou si tous...               NaN
# 1  Si vous ne contrôlez aucun monstre : Invoquez ...               NaN
# 2  À la fin de la Battle Phase, si votre adversai...               NaN
# 3  Ciblez 2 monstres dans votre Cimetière ; Invoq...               NaN
# 4  Activation de Compétence\n Retournez cette car...  [ Compétence / ]
#
#        Type_1
# 0       Magie
# 1       Magie
# 2       Piège
# 3       Piège
# 4  Compétence

# %% [markdown]
# # 12. Affichons le contenu de la premiere ligne et de la cinquieme colonne

# %%
df.iloc[0,4]
# Out:
# 'Si vous ne contrôlez aucun monstre, ou si tous les monstres que vous contrôlez sont des monstres "Chronomal" : vous pouvez payer 500 LP ; immédiatement après la résolution de cet effet, Invoquez Normalement 1 monstre "Chronomal" depuis votre main. Si un Monstre Xyz "Chronomal" ou "Numéro" que vous contrôlez va activer un effet en détachant du Matériel, vous pouvez envoyer cette carte au Cimetière au lieu d\'1 de ces Matériels. Vous ne pouvez utiliser chaque effet de "Temple Chronomal - Trilithe" qu\'une fois par tour.'

# %% [markdown]
# # 13. Affichons les 5 premieres des colonnes 5 à 7

# %%
colonneDescription = df ["Description"]
colonneType_1 = df ["Niveau"]
colonneType_2 = df ["Attribut"]
pd.concat([df ["Description"], df ["Niveau"], df ["Attribut"]], axis = 1).head(5)
# Out:
#                                          Description  Niveau Attribut
# 0  Si vous ne contrôlez aucun monstre, ou si tous...     NaN      NaN
# 1  Si vous ne contrôlez aucun monstre : Invoquez ...     NaN      NaN
# 2  À la fin de la Battle Phase, si votre adversai...     NaN      NaN
# 3  Ciblez 2 monstres dans votre Cimetière ; Invoq...     NaN      NaN
# 4  Activation de Compétence\n Retournez cette car...     NaN      NaN

# %% [markdown]
# # avec ilock

# %%
df.iloc[0:5, 4:7]
# Out:
#                                          Description  Niveau Attribut
# 0  Si vous ne contrôlez aucun monstre, ou si tous...     NaN      NaN
# 1  Si vous ne contrôlez aucun monstre : Invoquez ...     NaN      NaN
# 2  À la fin de la Battle Phase, si votre adversai...     NaN      NaN
# 3  Ciblez 2 monstres dans votre Cimetière ; Invoq...     NaN      NaN
# 4  Activation de Compétence\n Retournez cette car...     NaN      NaN

# %% [markdown]
# # 14. copions le dataset

# %%
SET = df[(df["Type_1"] == "Monstre")]
SET
# Out:
#                             Nom   Type_1                          Type_2  \
# 9                         Abaki  Monstre               [ Démon / Effet ]
# 10                Abare Ushioni  Monstre       [ Bête-Guerrier / Effet ]
# 11        Abanc le Mythologique  Monstre  [ Bête / Syntoniseur / Effet ]
# 12             Abeille Automate  Monstre             [ Insecte / Effet ]
# 13            Abeille Cuirassée  Monstre             [ Insecte / Effet ]
# ...                         ...      ...                             ...
# 10831       ZW - Lance Unicorne  Monstre                [ Bête / Effet ]
# 10832  ZW - Pégase Double Sabre  Monstre                [ Bête / Effet ]
# 10833   ZW - Porteur de Tornade  Monstre              [ Dragon / Effet ]
# 10834       ZW - Serres d'Aigle  Monstre          [ Bête-Ailée / Effet ]
# 10835        ZW - Vent Sylphide  Monstre                [ Bête / Effet ]
#
#       Icône                                        Description  Niveau  \
# ...

# %% [markdown]
# # pour magie

# %%
SET = df[(df["Type_1"] == "Magie")]
SET
# Out:
#                                     Nom Type_1 Type_2       Icône  \
# 0           Temple Chronomal - Trilithe  Magie    NaN     Continu
# 1                    1er Mouvement Solo  Magie    NaN         NaN
# 5                        À Moitié Fermé  Magie    NaN  Jeu Rapide
# 7                   A.I. Vous Rencontre  Magie    NaN         NaN
# 19                 Abondance du Cristal  Magie    NaN         NaN
# ...                                 ...    ...    ...         ...
# 10803         Zone de Danger Surnaturel  Magie    NaN     Continu
# 10804                   Zone de Défense  Magie    NaN     Terrain
# 10806  Zone de Neutralisation des Sorts  Magie    NaN     Continu
# 10808                   Zone De Progrès  Magie    NaN     Continu
# 10809           Zone de Repos Psychique  Magie    NaN         NaN
#
#                                              Description  Niveau Attribut  \
# 0      Si vous ne contrôlez aucun monstre, ou si tous...     NaN      NaN
# ...

# %% [markdown]
# # 15. Affichons les infos sur cette variable

# %%
SET.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 10809
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nom          2097 non-null   object
#  1   Type_1       2097 non-null   object
#  2   Type_2       0 non-null      object
#  3   Icône        1288 non-null   object
#  4   Description  2096 non-null   object
#  5   Niveau       0 non-null      float64
#  6   Attribut     0 non-null      object
#  7   ATK          0 non-null      object
#  8   DEF          0 non-null      object
#  9   Prix         2097 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 180.2+ KB

# %% [markdown]
# # 16. Affichons le dataset avec les valeurs de type_1 = magie et icone = continue

# %%
K = df[(df['Type_1'] == "Magie") & (df["Icône"] == "Continu")]
K
# Out:
#                                     Nom Type_1 Type_2    Icône  \
# 0           Temple Chronomal - Trilithe  Magie    NaN  Continu
# 23                  Absorption de l'Âme  Magie    NaN  Continu
# 26                  Absorption de Magie  Magie    NaN  Continu
# 29             Absorption Super Solaire  Magie    NaN  Continu
# 35              Accélérateur de Flammes  Magie    NaN  Continu
# ...                                 ...    ...    ...      ...
# 10652     Walhalla, Sanctuaire du Déchu  Magie    NaN  Continu
# 10773                        Zérozérock  Magie    NaN  Continu
# 10803         Zone de Danger Surnaturel  Magie    NaN  Continu
# 10806  Zone de Neutralisation des Sorts  Magie    NaN  Continu
# 10808                   Zone De Progrès  Magie    NaN  Continu
#
#                                              Description  Niveau Attribut  \
# 0      Si vous ne contrôlez aucun monstre, ou si tous...     NaN      NaN
# ...

# %% [markdown]
# # 17. convertissons

# %%
df["ATK"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15384/2994552902.py in <module>
# ----> 1 df["ATK"].astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %% [markdown]
# # ca ne donne pas un resultat direct parcequ'il y aussi des objects. ainsi il faut d'abord convertir en string

# %%
df["Nom"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15384/2145770805.py in <module>
# ----> 1 df["Nom"].astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
df["Prix"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15384/2072573934.py in <module>
# ----> 1 df["Prix"].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
df = pd.concat([df["Type_2"],df["ATK"]], axis = 1)
df.dropna()
# Out:
#                                Type_2   ATK
# 9                   [ Démon / Effet ]  1700
# 10          [ Bête-Guerrier / Effet ]  1200
# 11     [ Bête / Syntoniseur / Effet ]  1000
# 12                [ Insecte / Effet ]   100
# 13                [ Insecte / Effet ]  1600
# ...                               ...   ...
# 10831                [ Bête / Effet ]  1900
# 10832                [ Bête / Effet ]  1000
# 10833              [ Dragon / Effet ]  1300
# 10834          [ Bête-Ailée / Effet ]  2000
# 10835                [ Bête / Effet ]   800
#
# [6959 rows x 2 columns]

# %% [markdown]
# # Création d'un fichier CSV qui va contenir tout nos fichier

# %%
SET.to_csv("Yugioh_Magie.csv", index = False)
